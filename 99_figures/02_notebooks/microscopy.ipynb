# %%
from interactive_export_staged import TissueAligner
from interactive_export_staged import RegionExporter

# %% [markdown]
# ### Figure 1e control

# %%
from interactive_export_staged import TissueAligner
aligner = TissueAligner(czi_path="../01_data/E241208D_BCRNQ-A25_PX3J.czi",
                        output_filename="Figure_1c_control")
aligner.show()

# %%
exporter = RegionExporter(
    stage1_npy="../01_data/microscopy/Figure_1c_control_stage1.npy",
    stage1_params="../01_data/microscopy/Figure_1c_control_stage1_params.json",
    params_file="../01_data/microscopy/Figure_1c_control_1_parameters.json",
    output_filename="../03_output/01_main_figures/Figure_1c_control_1",
)
exporter.show()

# %%
exporter = RegionExporter(
    stage1_npy="../01_data/microscopy/Figure_1c_control_stage1.npy",
    stage1_params="../01_data/microscopy/Figure_1c_control_stage1_params.json",
    params_file="../01_data/microscopy/Figure_1c_control_2_parameters.json",
    output_filename="../03_output/01_main_figures/Figure_1c_control_2",
)
exporter.show()

# %% [markdown]
# ### Figure 1e mild/moderate

# %%
from interactive_export_staged import TissueAligner
aligner = TissueAligner(czi_path="../01_data/microscopy/E241208D_B4TPY-A25_PX3J.czi",
                        output_filename="Figure_1c_mildmoderate")
aligner.show()

# %%
exporter = RegionExporter(
    stage1_npy="../01_data/microscopy/Figure_1c_mildmoderate_stage1.npy",
    stage1_params="../01_data/microscopy/Figure_1c_mildmoderate_stage1_params.json",
    params_file="../01_data/microscopy/Figure_1c_mildmoderate_2_parameters.json",
    output_filename="../03_output/01_main_figures/Figure_1c_mildmoderate_2",
)
exporter.show()

# %% [markdown]
# ### Figure 1e Severe

# %%
from interactive_export_staged import TissueAligner
aligner = TissueAligner(czi_path="../01_data/CureAS_Severe_AV_18285BH1_H-E.czi",
                        output_filename="../01_data/microscopy/Figure_1c_severe")
aligner.show()

# %%
exporter = RegionExporter(
    stage1_npy="../01_data/microscopy/Figure_1c_severe_stage1.npy",
    stage1_params="../01_data/microscopy/Figure_1c_severe_stage1_params.json",
    params_file="../01_data/microscopy/Figure_1c_severe_1_parameters.json",
    output_filename="../03_output/01_main_figures/Figure_1c_severe_1",
)
exporter.show()
exporter = RegionExporter(
    stage1_npy="../01_data/microscopy/Figure_1c_severe_stage1.npy",
    stage1_params="../01_data/microscopy/Figure_1c_severe_stage1_params.json",
    params_file="../01_data/microscopy/Figure_1c_severe_2_parameters.json",
    output_filename="../03_output/01_main_figures/Figure_1c_severe_2",
)
exporter.show()
exporter = RegionExporter(
    stage1_npy="../01_data/microscopy/Figure_1c_severe_stage1.npy",
    stage1_params="../01_data/microscopy/Figure_1c_severe_stage1_params.json",
    params_file="../01_data/microscopy/Figure_1c_severe_3_parameters.json",
    output_filename="../03_output/01_main_figures/Figure_1c_severe_3",
)
exporter.show()

# %% [markdown]
# ### Figure 2j Normal

# %%
from interactive_export_staged import TissueAligner
aligner = TissueAligner(czi_path="../01_data/microscopy/E250609D_BQCK7-A12_PAFA.czi",output_dir="../01_data/microscopy/",
                        output_filename="Figure_2j_normal")
aligner.show()

# %%
from interactive_export_staged import RegionExporter
exporter = RegionExporter(
    stage1_npy="../01_data/microscopy/Figure_2j_normal_stage1.npy",
    stage1_params="../01_data/microscopy/Figure_2j_normal_stage1_params.json",
    params_file="../01_data/microscopy/Figure_2j_normal_parameters.json", 
    output_filename="Figure_2j_normal", output_dir="../03_output/01_main_figures/"
)
exporter.show()

# %% [markdown]
# ### Figure 2j progressive

# %%
from interactive_export_staged import TissueAligner
aligner = TissueAligner(czi_path="../01_data/microscopy/E250609D_B4TPY-A12_PAFA.czi",
                        output_filename="../01_data/microscopy/Figure_2j_progressive", 
                        output_dir="../01_data/microscopy/")
aligner.show()

# %%
from interactive_export_staged import RegionExporter
exporter = RegionExporter(
    stage1_npy='../01_data/microscopy/Figure_2j_progressive_stage1.npy',
    stage1_params='../01_data/microscopy/Figure_2j_progressive_stage1_params.json',
    params_file="../01_data/microscopy/Figure_2j_progressive_parameters.json", 
    output_filename="Figure_2j_progressive", output_dir="../03_output/01_main_figures/"
)
exporter.show()

# %% [markdown]
# ### Figure 2j Severe

# %%
from interactive_export_staged import TissueAligner
aligner = TissueAligner(czi_path="../01_data/microscopy/E250609D_B4TPY-A12_PAFA.czi",
                        output_filename="Figure_2j_severe", 
                        output_dir="../01_data/microscopy/")
aligner.show()

# %%
exporter = RegionExporter(
    stage1_npy='../01_data/microscopy/Figure_2j_severe_stage1.npy',
    stage1_params='../01_data/microscopy/Figure_2j_severe_stage1_params.json',
    params_file="../01_data/microscopy/Figure_2j_severe-1_parameters.json", 
    output_filename="Figure_2j_severe-1", output_dir="../01_data/microscopy/"
)
exporter.show()

# %%
exporter = RegionExporter(
    stage1_npy='../01_data/microscopy/Figure_2j_severe_stage1.npy',
    stage1_params='../01_data/microscopy/Figure_2j_severe_stage1_params.json',
    params_file="../01_data/microscopy/Figure_2j_severe-2_parameters.json", 
    output_filename="Figure_2j_severe-2", output_dir="../01_data/microscopy/"
)
exporter.show()

# %% [markdown]
# ### Supplemental Figure 5 Primary Antibody

# %%
from interactive_export_staged import TissueAligner
aligner = TissueAligner(czi_path="../01_data/microscopy/E250609D_BIGDK-A09_PAFA.czi",
                        output_filename="Supplemental_Figure_5_Primary_Ab", 
                        output_dir="../01_data/microscopy/")
aligner.show()

# %%
RegionExporter(
    stage1_npy='../01_data/microscopy/Supplemental_Figure_5_Primary_Ab_stage1.npy',
    stage1_params='../01_data/microscopy/Supplemental_Figure_5_Primary_Ab_stage1_params.json',
    output_dir="../03_output/02_supplemental_figures/"
  ).show()

# %% [markdown]
# ### Supplemental Figure 5 No Primary Antibody

# %%
from interactive_export_staged import TissueAligner
aligner = TissueAligner(czi_path="../01_data/microscopy/E250809D_BIGDK-B24_PAFA-NCTRL1.czi",
                        output_filename="Supplemental_Figure_5_No_Primary_Ab", 
                        output_dir="../01_data/microscopy/")
aligner.show()

# %%
RegionExporter(
    stage1_npy='../01_data/microscopy/Supplemental_Figure_5_No_Primary_Ab_stage1.npy',
    stage1_params='../01_data/microscopy/Supplemental_Figure_5_No_Primary_Ab_stage1_params.json',
    output_dir="../03_output/02_supplemental_figures/"
  ).show()

# %% [markdown]
# ### Supplemental Figure 5 Isotype Control

# %%
from interactive_export_staged import TissueAligner
aligner = TissueAligner(czi_path="../01_data/microscopy/E250809D_BIGDK-B23_PAFA-NCTRL2.czi",
                        output_filename="Supplemental_Figure_5_Isotype_Control",
                        output_dir="../01_data/microscopy/")
aligner.show()

# %%
RegionExporter(
    stage1_npy='../01_data/microscopy/Supplemental_Figure_5_Isotype_Control_stage1.npy',
    stage1_params='../01_data/microscopy/Supplemental_Figure_5_Isotype_Control_stage1_params.json',
    output_dir="../03_output/02_supplemental_figures/"
  ).show()
